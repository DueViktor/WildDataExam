# %%
import pandas as pd

# %%
fpath = "data/final_datasets/"
raw_data = pd.read_csv(fpath+'aggregated_dataset.csv',sep=';')
raw_data
# Out:
# /Users/askemeineche/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              date       id                                             corpus  \
# 0      2022-03-06   t7c3t7   sarn sauron coin bsc gem of 2022 launch now e...
# 1      2022-03-06   t7c9cs                         a proposal to you removed
# 2      2022-03-06   t7cbqa                                    time to buy nan
# 3      2022-03-06   t6xdmv  stupid question please excuse my ignorance can...
# 4      2022-03-06   t7cf3e                                        bitcoin nan
# ...           ...      ...                                                ...
# 77051  2022-09-18  iouvy8t  hi u alfador8 thanks for tipping u cryptoenthu...
# 77052  2022-09-18  iouw6s5                                       i m very new
# ...

# %%
def is_ln_bot(string):
    if isinstance(string,float):
        return string
    if 'lntipbot' in string or 'invoice' in string or 'balance' in string or 'deposit' in string or 'withdraw' in string or 'execute' in string:
        return True
    else:
        return False
    
    
def is_company_bot(string):
    if isinstance(string,float):
        return string
    if 'zelcore' in string:
        return True
    else:
        return False
    

def is_mod_bot(string):
    if isinstance(string,float):
        return string
    if 'flagged for removal' in string or 'i am a bot' in string:
        return True
    else:
        return False


raw_data['lnbot'] = raw_data['corpus'].apply(lambda x: is_ln_bot(x))
raw_data['zelcore'] = raw_data['corpus'].apply(lambda x: is_company_bot(x))
raw_data['mod'] = raw_data['corpus'].apply(lambda x: is_mod_bot(x))
raw_data.loc[raw_data['mod']==1].shape
# Out:
# (232, 24)

# %%
raw_data.to_csv('data/final_datasets/bot_annotated_dataset.csv',index=None,sep=';')

# %%
raw_data['date'].max()
# Out:
# '2022-09-18'

# %%
raw_data.loc[raw_data['romance']>0.81].sort_values('romance',ascending=False)['corpus'].tolist()
# Out:
# ['is what you like doing really your true passion or is it because of someone else is what you like doing really your true passion or is it because of someone else want help to find out if it is your true passion email honeymoon mindset academy james passionateliferanch com mailto james passionateliferanch com amp x200b https www instagram com p cyuodrpo wz utm source ig web copy link https www instagram com p cyuodrpo wz utm source ig web copy link amp x200b life relationship hobby business love passion trueself',
#  'i love bitcoin',
#  'god creates human god creates human human creates bitcoin god now that s what i m talking about peeks satoshi privkeys ',
#  'love of his life eh mhm',
#  'i just love teasing these old motherfuckers who hates btc ',
#  'i would make sweet love to natalie',
#  'fuckin love this ahahahahahaha',
#  'i wish to give the person i love this beautiful flowers nan',
#  'shorts love coming back to get rekt ',
# ...

# %%
raw_data.sort_values('romance',ascending=False).head(1)[['corpus','romance']]
# Out:
#                                                  corpus   romance
# 5372  is what you like doing really your true passio...  0.996767

# %%
raw_data.sort_values('romance',ascending=False).head(1)['corpus'].values[0]
# Out:
# 'is what you like doing really your true passion or is it because of someone else is what you like doing really your true passion or is it because of someone else want help to find out if it is your true passion email honeymoon mindset academy james passionateliferanch com mailto james passionateliferanch com amp x200b https www instagram com p cyuodrpo wz utm source ig web copy link https www instagram com p cyuodrpo wz utm source ig web copy link amp x200b life relationship hobby business love passion trueself'

# %%
raw_data = raw_data.dropna(subset=['corpus'])
raw_data.loc[raw_data.corpus.str.contains(" a house or car w")]
# Out:
#              date      id                                             corpus  \
# 16147  2022-02-26  t0yv62  is bitcoin an independent asset if you had bit...
#
#       text_type  conflict  similarity  knowledge     power    status  \
# 16147      post  0.890907    0.003702   0.995712  0.976996  0.065564
#
#         support  ...          High           Low          Mean         Close  \
# 16147  0.000746  ...  40005.348726  38702.533706  39353.941216  39105.147816
#
#        event_id  event_type  period_type  lnbot  zelcore    mod
# 16147       3.0    positive       before  False    False  False
#
# [1 rows x 24 columns]
